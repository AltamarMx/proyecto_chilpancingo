# %%
import pandas as pd
import matplotlib.pyplot as plt
from readeplus_sql import *

# %%
cb = read_eplusql("../idf/cb/simulacion.sql",read='all') # by default reads everything

# %%
cs = cb.construction_systems
cs
# Out:
# array(['ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 2',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 3',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 4',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 5',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 6',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 7-8', 'CONCRETO',
#        'IMPER_CONCRETO_YESO', 'EXTERIOR DOOR', 'INTERIOR CEILING',
#        'INTERIOR FLOOR', 'INTERIOR WALL', 'INTERIOR DOOR',
#        'INTERIOR PARTITION', 'PUERTA',
#        'EXTSLABCARPET 4IN CLIMATEZONE 1-8',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2-5',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 7-8',
#        'ASHRAE 189.1-2009 EXTROOF METAL CLIMATEZONE 6',
#        'MORTERO_TABIQUE_YESO', 'YESO_TABIQUE_YESO', 'INTERIOR WINDOW',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 1',
# ...

# %%
cb.get_construction(['MORTERO_TABIQUE_YESO'])
# Out:
# Construction system:MORTERO_TABIQUE_YESO
# Total thickness    :0.15 m
# Total layers:[3]
# InsideAbsorpVis:[0.3]
# OutsideAbsorpVis:[0.4]
# OutsideAbsorpSolar:[0.4]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_920d6_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_920d6_row0_col0" class="data row0 col0" >MORTERO</td>
#       <td id="T_920d6_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_920d6_row0_col2" class="data row0 col2" >1800.000000</td>
#       <td id="T_920d6_row0_col3" class="data row0 col3" >1000.000000</td>
# ...

# %%
variables = cb.vars
variables
# Out:
# array(['Environment:Site Outdoor Air Drybulb Temperature (C)',
#        'THERMAL ZONE: BANO:Zone Mean Air Temperature (C)',
#        'THERMAL ZONE: ESTANCIA:Zone Mean Air Temperature (C)',
#        'THERMAL ZONE: RECAMARA1:Zone Mean Air Temperature (C)',
#        'THERMAL ZONE: RECAMARA2:Zone Mean Air Temperature (C)'],
#       dtype=object)

# %%
data_cb =  cb.get_data(variables)
data_cb.plot(subplots=True,figsize=(12,10))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)
